# %%
import gym
env = gym.make('CartPole-v0')
# env.reset()
for _ in range(10):
    env.reset()
    screenshot = env.render(mode='rgb_array')
    plt.imshow(screenshot)
    plt.show()
    env.step(env.action_space.sample()) # take a random action
# Out:
# [2017-06-29 18:15:03,951] Making new env: CartPole-v0

# %%
import gym
import matplotlib.pyplot as plt
# %matplotlib inline

env = gym.make('Breakout-v0') # insert your favorite environment
render = lambda : plt.imshow(env.render(mode='rgb_array'))
env.reset()
render();
# Out:
# [2017-06-29 18:14:02,922] Making new env: Breakout-v0
